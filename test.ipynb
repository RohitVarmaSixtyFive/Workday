# %%
from final import JobApplicationBot

bot = JobApplicationBot()

try:
    auth_choice = int(input("Enter 1 for sign in or 2 for sign up: "))
except ValueError:
    auth_choice = 1

# Get company choice
print("Available companies:")
for i, company in enumerate(bot.company_urls.keys(), 1):
    print(f"{i}. {company.title()}")

try:
    company_choice = int(input("Select company (1-5): "))
    company_names = list(bot.company_urls.keys())
    selected_company = company_names[company_choice - 1]
except (ValueError, IndexError):
    selected_company = "harris"  # Default
bot.company = selected_company
print(f"Selected company: {selected_company.title()}")
# Out:
# Available companies:
# 1. Nvidia
# 2. Salesforce
# 3. Hitachi
# 4. Icf
# 5. Harris
# Selected company: Nvidia

# %%
print("=== Starting Job Application Automation ===")

# Initialize browser
await bot.initialize_browser(headless=False)

# Navigate to job

await bot.navigate_to_job(selected_company)

# Handle authentication
auth_success = await bot.handle_authentication(auth_choice)
if not auth_success:
    print("Authentication failed")

# # Process application form
# await bot.process_application_form()

# # Submit final form
# await bot.submit_form()

print("=== Job Application Completed Successfully ===")
# Out:
# === Starting Job Application Automation ===
# Navigated to nvidia job application page
# Filled email: lmei11111@gmail.com
# Filled password
# Filled verify password
# Checked create account checkbox
# Clicked create account submit button
# === Job Application Completed Successfully ===

# %%
import asyncio

await asyncio.sleep(10)
main_page = await bot.page.query_selector('div[data-automation-id="applyFlowPage"]')

await bot._process_personal_information_section(main_page)
# Out:
# Processing Personal Information section
# Found label by ID: How Did You Hear About Us?*
# --------------------------------
# Processing element 1: Input ID: unknown, Question: How Did You Hear About Us?, Type: unknown
# Processing form element: How Did You Hear About Us?
# AI response for field 'How Did You Hear About Us?': LinkedIn
# Filling MultiInputContainer for unknown with responses: ['LinkedIn']
# Found label by ID: How Did You Hear About Us?*
# It is nested field:
# Adding item: LinkedIn
# No first-level options found for 'LinkedIn'
# Successfully added item: LinkedIn
# Found label by ID: Yes
# Radio group 'Have you previously worked for NVIDIA as an employee or contractor?*' has 2 options at indices: [2, 3]
# Found radio group with indices: [2, 3]
# Found label by ID: Yes
# Found label by ID: No
# Processing radio group: 'Have you previously worked for NVIDIA as an employee or contractor?*' with options: ['Yes', 'No']
# Is the option checked False?
# ✅ Selected radio option: 'No' for question: 'Have you previously worked for NVIDIA as an employee or contractor?*'
# Found label by ID: Country*
# --------------------------------
# Processing element 4: Input ID: listbox, Question: Country, Type: button
# Processing form element: Country
# AI response for field 'Country': United States of America
# Selected option: United States of America
# Found label by form field: Country*
# ⏩ Skipping duplicate question at index 5: 'Country'
# Found label by ID: First Name*
# --------------------------------
# Processing element 6: Input ID: unknown, Question: First Name, Type: text
# Processing form element: First Name
# AI response for field 'First Name': Lin
# Filled unknown with: Lin
# Found label by ID: Last Name*
# --------------------------------
# Processing element 7: Input ID: unknown, Question: Last Name, Type: text
# Processing form element: Last Name
# AI response for field 'Last Name': Mei
# Filled unknown with: Mei
# Found label by ID: I have a preferred name
# --------------------------------
# Processing element 8: Input ID: unknown, Question: I have a preferred name, Type: checkbox
# Processing form element: I have a preferred name
# AI response for field 'I have a preferred name': False
# Found label by ID: Address Line 1
# --------------------------------
# Processing element 9: Input ID: unknown, Question: Address Line 1, Type: text
# Processing form element: Address Line 1
# AI response for field 'Address Line 1': House 36, Sunset Boulevard
# Filled unknown with: House 36, Sunset Boulevard
# Found label by ID: City
# --------------------------------
# Processing element 10: Input ID: unknown, Question: City, Type: text
# Processing form element: City
# AI response for field 'City': San Diego
# Filled unknown with: San Diego
# Found label by ID: State
# --------------------------------
# Processing element 11: Input ID: listbox, Question: State, Type: button
# Processing form element: State
# AI response for field 'State': California
# Selected option: California
# Found label by form field: State
# ⏩ Skipping duplicate question at index 12: 'State'
# Found label by ID: Postal Code
# --------------------------------
# Processing element 13: Input ID: unknown, Question: Postal Code, Type: text
# Processing form element: Postal Code
# AI response for field 'Postal Code': 90080
# Filled unknown with: 90080
# Found label by ID: Phone Device Type*
# --------------------------------
# Processing element 14: Input ID: listbox, Question: Phone Device Type, Type: button
# Processing form element: Phone Device Type
# AI response for field 'Phone Device Type': Home Cellular
# Selected option: Home Cellular
# Found label by form field: Phone Device Type*
# ⏩ Skipping duplicate question at index 15: 'Phone Device Type'
# Found label by ID: Country Phone Code*
# --------------------------------
# Processing element 16: Input ID: unknown, Question: Country Phone Code, Type: unknown
# Processing form element: Country Phone Code
# AI response for field 'Country Phone Code': United States of America
# Filling MultiInputContainer for unknown with responses: ['United States of America']
# Found label by ID: Country Phone Code*
# It is single
# Adding item: United States of America
# No dropdown options found for 'United States of America'
# Successfully added item: United States of America
# Found label by ID: Phone Number*
# --------------------------------
# Processing element 17: Input ID: unknown, Question: Phone Number, Type: text
# Processing form element: Phone Number
# AI response for field 'Phone Number': 6504508692
# Filled unknown with: 6504508692
# Found label by ID: Phone Extension
# --------------------------------
# Processing element 18: Input ID: unknown, Question: Phone Extension, Type: text
# Processing form element: Phone Extension
# AI response for field 'Phone Extension':
# Filled unknown with:
# Clicking Next button

# %%
import asyncio

await asyncio.sleep(5)
main_page = await bot.page.query_selector('div[data-automation-id="applyFlowPage"]')
if not main_page:
    print("Main page container not found")
else:
    print("Main page container found, proceeding with section processing")

# Find all sections in the application
sections = await main_page.query_selector_all('div[role="group"][aria-labelledby]')
print(f"Found {len(sections)} sections to process")
for section in sections:
    aria_labelledby = await section.get_attribute('aria-labelledby')
    if not aria_labelledby:
        print("Section without aria-labelledby found, skipping")
        continue

    print(f"Processing section: {aria_labelledby}")

for section in sections:
    aria_labelledby = await section.get_attribute('aria-labelledby')
    if not aria_labelledby:
        continue

    print(f"\n=== Processing section: {aria_labelledby} ===")
    
    # Process different section types
    if any(keyword in aria_labelledby.lower() for keyword in ["information", "personal"]):
        await bot._process_personal_information_section(section)
        pass
    elif any(keyword in aria_labelledby.lower() for keyword in ["work", "experience", "history"]):
        await bot._process_experience_section(section)
        pass
    elif any(keyword in aria_labelledby.lower() for keyword in ["education"]):
        await bot._process_education_section(section)
        pass
    elif any(keyword in aria_labelledby.lower() for keyword in ["language"]):
        await bot._process_language_section(section)
    elif any(keyword in aria_labelledby.lower() for keyword in ["skill"]):
        await bot._process_skills_section(section)
        pass
    elif any(keyword in aria_labelledby.lower() for keyword in ["resume", "document"]):
        await bot._process_resume_section(section)
        pass
    else:
        print(f"Unknown section type: {aria_labelledby}")
        await bot._process_generic_section(section, aria_labelledby)
# Out:
# Main page container found, proceeding with section processing
# Found 6 sections to process
# Processing section: Work-Experience-section
# Processing section: Education-section
# Processing section: Skills-section
# Processing section: Resume/CV-section
# Processing section: Websites-section
# Processing section: Social-Network-URLs-section
#
# === Processing section: Work-Experience-section ===
# Processing Work Experience section
# Found 2 experience entries
#
# === Filling experience 1 ===
# Clicked add button for experience 1
# Input ID: unknown, Question: UNLABELED, aria-labelledby: Work-Experience-1-panel
# Previous question: None, Previous type: None
# Found label by ID: Job Title*
# Input ID: unknown, Question: Job Title, aria-labelledby: Work-Experience-1-panel
# Previous question: None, Previous type: None
# Found label by ID: Company*
# Input ID: unknown, Question: Company, aria-labelledby: Work-Experience-1-panel
# Previous question: Job Title, Previous type: text
# Found label by ID: Location
# Input ID: unknown, Question: Location, aria-labelledby: Work-Experience-1-panel
# Previous question: Company, Previous type: text
# Found label by ID: I currently work here
# Input ID: unknown, Question: I currently work here, aria-labelledby: Work-Experience-1-panel
# Previous question: Location, Previous type: text
# Found label by form field: From*
# Input ID: dateSectionMonth-input, Question: From, aria-labelledby: Work-Experience-1-panel
# Previous question: I currently work here, Previous type: checkbox
# Found label by form field: From*
# Input ID: dateSectionYear-input, Question: From, aria-labelledby: Work-Experience-1-panel
# Previous question: From, Previous type: spinbutton
# Found label by form field: To*
# Input ID: dateSectionMonth-input, Question: To, aria-labelledby: Work-Experience-1-panel
# Previous question: From, Previous type: spinbutton
# Found label by form field: To*
# Input ID: dateSectionYear-input, Question: To, aria-labelledby: Work-Experience-1-panel
# Previous question: To, Previous type: spinbutton
# Found label by ID: Role Description
# Input ID: unknown, Question: Role Description, aria-labelledby: Work-Experience-1-panel
# Previous question: To, Previous type: spinbutton
# Input ID: add-button, Question: UNLABELED, aria-labelledby: Work-Experience-section
# Previous question: Role Description, Previous type: textarea
# Panel Elements Count: 10
# Element: UNLABELED, Type: unknown, Options: None
# Element: Job Title, Type: text, Options: None
# Element: Company, Type: text, Options: None
# Element: Location, Type: text, Options: None
# Element: I currently work here, Type: checkbox, Options: None
# Element: From, Type: spinbutton, Options: None
# Element: From, Type: spinbutton, Options: None
# Element: To, Type: spinbutton, Options: None
# Element: To, Type: spinbutton, Options: None
# Element: Role Description, Type: textarea, Options: None
# AI Response: {'[UNLABELED, unknown, unknown, Work-Experience-1-panel, button]': 'SKIP', '[Job Title, unknown, text, Work-Experience-1-panel, input]': 'Sr. Software Developer', '[Company, unknown, text, Work-Experience-1-panel, input]': 'OSIsoft LLC', '[Location, unknown, text, Work-Experience-1-panel, input]': 'San Francisco Bay Area - USA', '[I currently work here, unknown, checkbox, Work-Experience-1-panel, input]': True, '[From, dateSectionMonth-input, spinbutton, Work-Experience-1-panel, input]': '08', '[From, dateSectionYear-input, spinbutton, Work-Experience-1-panel, input]': '2023', '[To, dateSectionMonth-input, spinbutton, Work-Experience-1-panel, input]': 'SKIP', '[To, dateSectionYear-input, spinbutton, Work-Experience-1-panel, input]': 'SKIP', '[Role Description, unknown, textarea, Work-Experience-1-panel, textarea]': 'Developed high-throughput C# agent processing 150k+ time-series events/sec.\nDesigned MSI/bundle installers using WiX Toolset with CI/CD automation.\nIntegrated Azure DevOps pipelines with digital signing via Azure Key Vault.\nBuilt real-time monitoring using Azure Application Insights.\nReduced release time by 60% and incident response by 20%.\nSupported 4 enterprise-level systems and reduced production issues by 40%.'}
# Filling element unknown with response: SKIP
# Skipping input unknown as per AI response
# Filling element unknown with response: Sr. Software Developer
# Filled unknown with: Sr. Software Developer
# Filling element unknown with response: OSIsoft LLC
# Filled unknown with: OSIsoft LLC
# Filling element unknown with response: San Francisco Bay Area - USA
# Filled unknown with: San Francisco Bay Area - USA
# Filling element unknown with response: True
# Checked checkbox unknown
# Filling element dateSectionMonth-input with response: 08
# Filled spinbutton dateSectionMonth-input with: 08
# Filling element dateSectionYear-input with response: 2023
# Filled spinbutton dateSectionYear-input with: 2023
# Filling element dateSectionMonth-input with response: SKIP
# Skipping input dateSectionMonth-input as per AI response
# Filling element dateSectionYear-input with response: SKIP
# Skipping input dateSectionYear-input as per AI response
# Filling element unknown with response: Developed high-throughput C# agent processing 150k+ time-series events/sec.
# Designed MSI/bundle installers using WiX Toolset with CI/CD automation.
# Integrated Azure DevOps pipelines with digital signing via Azure Key Vault.
# Built real-time monitoring using Azure Application Insights.
# Reduced release time by 60% and incident response by 20%.
# Supported 4 enterprise-level systems and reduced production issues by 40%.
# Filled unknown with: Developed high-throughput C# agent processing 150k+ time-series events/sec.
# Designed MSI/bundle installers using WiX Toolset with CI/CD automation.
# Integrated Azure DevOps pipelines with digital signing via Azure Key Vault.
# Built real-time monitoring using Azure Application Insights.
# Reduced release time by 60% and incident response by 20%.
# Supported 4 enterprise-level systems and reduced production issues by 40%.
#
# === Filling experience 2 ===
# Clicked add button for experience 2
# Input ID: unknown, Question: UNLABELED, aria-labelledby: Work-Experience-1-panel
# Previous question: None, Previous type: None
# Found label by ID: Job Title*
# Input ID: unknown, Question: Job Title, aria-labelledby: Work-Experience-1-panel
# Previous question: None, Previous type: None
# Found label by ID: Company*
# Input ID: unknown, Question: Company, aria-labelledby: Work-Experience-1-panel
# Previous question: Job Title, Previous type: text
# Found label by ID: Location
# Input ID: unknown, Question: Location, aria-labelledby: Work-Experience-1-panel
# Previous question: Company, Previous type: text
# Found label by ID: I currently work here
# Input ID: unknown, Question: I currently work here, aria-labelledby: Work-Experience-1-panel
# Previous question: Location, Previous type: text
# Found label by form field: From*
# Input ID: dateSectionMonth-input, Question: From, aria-labelledby: Work-Experience-1-panel
# Previous question: I currently work here, Previous type: checkbox
# Found label by form field: From*
# Input ID: dateSectionYear-input, Question: From, aria-labelledby: Work-Experience-1-panel
# Previous question: From, Previous type: spinbutton
# Found label by ID: Role Description
# Input ID: unknown, Question: Role Description, aria-labelledby: Work-Experience-1-panel
# Previous question: From, Previous type: spinbutton
# Input ID: unknown, Question: UNLABELED, aria-labelledby: Work-Experience-2-panel
# Previous question: Role Description, Previous type: textarea
# Found label by ID: Job Title*
# Input ID: unknown, Question: Job Title, aria-labelledby: Work-Experience-2-panel
# Previous question: Role Description, Previous type: textarea
# Found label by ID: Company*
# Input ID: unknown, Question: Company, aria-labelledby: Work-Experience-2-panel
# Previous question: Job Title, Previous type: text
# Found label by ID: Location
# Input ID: unknown, Question: Location, aria-labelledby: Work-Experience-2-panel
# Previous question: Company, Previous type: text
# Found label by ID: I currently work here
# Input ID: unknown, Question: I currently work here, aria-labelledby: Work-Experience-2-panel
# Previous question: Location, Previous type: text
# Found label by form field: From*
# Input ID: dateSectionMonth-input, Question: From, aria-labelledby: Work-Experience-2-panel
# Previous question: I currently work here, Previous type: checkbox
# Found label by form field: From*
# Input ID: dateSectionYear-input, Question: From, aria-labelledby: Work-Experience-2-panel
# Previous question: From, Previous type: spinbutton
# Found label by form field: To*
# Input ID: dateSectionMonth-input, Question: To, aria-labelledby: Work-Experience-2-panel
# Previous question: From, Previous type: spinbutton
# Found label by form field: To*
# Input ID: dateSectionYear-input, Question: To, aria-labelledby: Work-Experience-2-panel
# Previous question: To, Previous type: spinbutton
# Found label by ID: Role Description
# Input ID: unknown, Question: Role Description, aria-labelledby: Work-Experience-2-panel
# Previous question: To, Previous type: spinbutton
# Input ID: add-button, Question: UNLABELED, aria-labelledby: Work-Experience-section
# Previous question: Role Description, Previous type: textarea
# Panel Elements Count: 10
# Element: UNLABELED, Type: unknown, Options: None
# Element: Job Title, Type: text, Options: None
# Element: Company, Type: text, Options: None
# Element: Location, Type: text, Options: None
# Element: I currently work here, Type: checkbox, Options: None
# Element: From, Type: spinbutton, Options: None
# Element: From, Type: spinbutton, Options: None
# Element: To, Type: spinbutton, Options: None
# Element: To, Type: spinbutton, Options: None
# Element: Role Description, Type: textarea, Options: None
# AI Response: {'[UNLABELED, unknown, unknown, Work-Experience-2-panel, button]': 'SKIP', '[Job Title, unknown, text, Work-Experience-2-panel, input]': 'Software Engineer', '[Company, unknown, text, Work-Experience-2-panel, input]': 'Cybage Software', '[Location, unknown, text, Work-Experience-2-panel, input]': 'Pune - India', '[I currently work here, unknown, checkbox, Work-Experience-2-panel, input]': False, '[From, dateSectionMonth-input, spinbutton, Work-Experience-2-panel, input]': '02', '[From, dateSectionYear-input, spinbutton, Work-Experience-2-panel, input]': '2016', '[To, dateSectionMonth-input, spinbutton, Work-Experience-2-panel, input]': '06', '[To, dateSectionYear-input, spinbutton, Work-Experience-2-panel, input]': '2017', '[Role Description, unknown, textarea, Work-Experience-2-panel, textarea]': 'Developed scalable apps in C# using Entity Framework with SQL Server.\nOptimized database operations with stored procedures and triggers.\nBuilt chatbot with Microsoft Bot Framework + LUIS for Skype integration.\nReduced Tier-1 support volume by 40% and response time by 60%.'}
# Filling element unknown with response: SKIP
# Skipping input unknown as per AI response
# Filling element unknown with response: Software Engineer
# Filled unknown with: Software Engineer
# Filling element unknown with response: Cybage Software
# Filled unknown with: Cybage Software
# Filling element unknown with response: Pune - India
# Filled unknown with: Pune - India
# Filling element unknown with response: False
# Filling element dateSectionMonth-input with response: 02
# Filled spinbutton dateSectionMonth-input with: 02
# Filling element dateSectionYear-input with response: 2016
# Filled spinbutton dateSectionYear-input with: 2016
# Filling element dateSectionMonth-input with response: 06
# Filled spinbutton dateSectionMonth-input with: 06
# Filling element dateSectionYear-input with response: 2017
# Filled spinbutton dateSectionYear-input with: 2017
# Filling element unknown with response: Developed scalable apps in C# using Entity Framework with SQL Server.
# Optimized database operations with stored procedures and triggers.
# Built chatbot with Microsoft Bot Framework + LUIS for Skype integration.
# Reduced Tier-1 support volume by 40% and response time by 60%.
# Filled unknown with: Developed scalable apps in C# using Entity Framework with SQL Server.
# Optimized database operations with stored procedures and triggers.
# Built chatbot with Microsoft Bot Framework + LUIS for Skype integration.
# Reduced Tier-1 support volume by 40% and response time by 60%.
#
# === Processing section: Education-section ===
# Processing Education section
# Found 2 education entries
#
# === Filling education 1 ===
# Clicked add button for education 1
# Input ID: unknown, Question: UNLABELED, aria-labelledby: Education-1-panel
# Previous question: None, Previous type: None
# Found label by ID: School or University*
# Input ID: unknown, Question: School or University, aria-labelledby: Education-1-panel
# Previous question: None, Previous type: None
# Found label by ID: Degree*
# Input ID: listbox, Question: Degree, aria-labelledby: Education-1-panel
# Previous question: School or University, Previous type: text
# Found label by form field: Degree*
# Input ID: unknown, Question: Degree, aria-labelledby: Education-1-panel
# Previous question: Degree, Previous type: button
# Found label by ID: Field of Study
# Input ID: unknown, Question: Field of Study, aria-labelledby: Education-1-panel
# Previous question: Degree, Previous type: text
# Found label by aria-label: The field will alphabetically return the first 100 results and can also return specified matches.
# Input ID: unknown, Question: The field will alphabetically return the first 100 results and can also return specified matches., aria-labelledby: Education-1-panel
# Previous question: Field of Study, Previous type: unknown
# Found label by ID: Overall Result (GPA)
# Input ID: unknown, Question: Overall Result (GPA), aria-labelledby: Education-1-panel
# Previous question: The field will alphabetically return the first 100 results and can also return specified matches., Previous type: button
# Found label by form field: From
# Input ID: dateSectionYear-input, Question: From, aria-labelledby: Education-1-panel
# Previous question: Overall Result (GPA), Previous type: text
# Found label by form field: To (Actual or Expected)
# Input ID: dateSectionYear-input, Question: To (Actual or Expected), aria-labelledby: Education-1-panel
# Previous question: From, Previous type: spinbutton
# Input ID: add-button, Question: UNLABELED, aria-labelledby: Education-section
# Previous question: To (Actual or Expected), Previous type: spinbutton
# Panel Elements Count: 9
# Element: UNLABELED, Type: unknown, Options: None
# Element: School or University, Type: text, Options: None
# Element: Degree, Type: button, Options: ['Select One', 'Post-diploma studies', 'BTECH', 'MTECH', 'University Diploma', 'Associates', 'Technical/other training', 'Some college', 'PhD', 'Some post college', 'No Degree', 'MBA', 'Masters', 'Juris Doctor', 'High School', 'Doctorate', 'Bachelors']
# Element: Degree, Type: text, Options: None
# Element: Field of Study, Type: unknown, Options: None
# Element: The field will alphabetically return the first 100 results and can also return specified matches., Type: button, Options: None
# Element: Overall Result (GPA), Type: text, Options: None
# Element: From, Type: spinbutton, Options: None
# Element: To (Actual or Expected), Type: spinbutton, Options: None
# AI Response: {'[UNLABELED, unknown, unknown, Education-1-panel, button]': 'SKIP', '[School or University, unknown, text, Education-1-panel, input]': 'University of California, Davis', '[Degree, listbox, button, Education-1-panel, button]': 'Masters', '[Degree, unknown, text, Education-1-panel, input]': 'SKIP', '[Field of Study, unknown, unknown, Education-1-panel, input]': 'Computer Science', '[The field will alphabetically return the first 100 results and can also return specified matches., unknown, button, Education-1-panel, button]': 'SKIP', '[Overall Result (GPA), unknown, text, Education-1-panel, input]': 'SKIP', '[From, dateSectionYear-input, spinbutton, Education-1-panel, input]': '2016', '[To (Actual or Expected), dateSectionYear-input, spinbutton, Education-1-panel, input]': '2018'}
# Filling element unknown with response: SKIP
# Skipping input unknown as per AI response
# Filling element unknown with response: University of California, Davis
# Filled unknown with: University of California, Davis
# Filling element listbox with response: Masters
# Selected option: Masters
# Filling element unknown with response: SKIP
# Skipping input unknown as per AI response
# Filling element unknown with response: Computer Science
# Filling MultiInputContainer for unknown with responses: ['Computer Science']
# Found label by ID: Field of Study
# It is single
# Adding item: Computer Science
# Found 5 options for 'Computer Science':
#   - Computational Science & Engineering
#   - Computer & Info Science
#   - Computer Science
# Selected: 'Computer Science' (score: 100.0)
# Successfully added item: Computer Science
# Filling element unknown with response: SKIP
# Skipping input unknown as per AI response
# Filling element unknown with response: SKIP
# Skipping input unknown as per AI response
# Filling element dateSectionYear-input with response: 2016
# Filled spinbutton dateSectionYear-input with: 2016
# Filling element dateSectionYear-input with response: 2018
# Filled spinbutton dateSectionYear-input with: 2018
#
# === Filling education 2 ===
# Clicked add button for education 2
# Input ID: unknown, Question: UNLABELED, aria-labelledby: Education-1-panel
# Previous question: None, Previous type: None
# Found label by ID: School or University*
# Input ID: unknown, Question: School or University, aria-labelledby: Education-1-panel
# Previous question: None, Previous type: None
# Found label by ID: Degree*
# Input ID: listbox, Question: Degree, aria-labelledby: Education-1-panel
# Previous question: School or University, Previous type: text
# Found label by form field: Degree*
# Input ID: unknown, Question: Degree, aria-labelledby: Education-1-panel
# Previous question: Degree, Previous type: button
# Found label by ID: Field of Study
# Input ID: unknown, Question: Field of Study, aria-labelledby: Education-1-panel
# Previous question: Degree, Previous type: text
# Found label by aria-label: The field will alphabetically return the first 100 results and can also return specified matches.
# Input ID: unknown, Question: The field will alphabetically return the first 100 results and can also return specified matches., aria-labelledby: Education-1-panel
# Previous question: Field of Study, Previous type: unknown
# Found label by ID: Overall Result (GPA)
# Input ID: unknown, Question: Overall Result (GPA), aria-labelledby: Education-1-panel
# Previous question: The field will alphabetically return the first 100 results and can also return specified matches., Previous type: button
# Found label by form field: From
# Input ID: dateSectionYear-input, Question: From, aria-labelledby: Education-1-panel
# Previous question: Overall Result (GPA), Previous type: text
# Found label by form field: To (Actual or Expected)
# Input ID: dateSectionYear-input, Question: To (Actual or Expected), aria-labelledby: Education-1-panel
# Previous question: From, Previous type: spinbutton
# Input ID: unknown, Question: UNLABELED, aria-labelledby: Education-2-panel
# Previous question: To (Actual or Expected), Previous type: spinbutton
# Found label by ID: School or University*
# Input ID: unknown, Question: School or University, aria-labelledby: Education-2-panel
# Previous question: To (Actual or Expected), Previous type: spinbutton
# Found label by ID: Degree*
# Input ID: listbox, Question: Degree, aria-labelledby: Education-2-panel
# Previous question: School or University, Previous type: text
# Found label by form field: Degree*
# Input ID: unknown, Question: Degree, aria-labelledby: Education-2-panel
# Previous question: Degree, Previous type: button
# Found label by ID: Field of Study
# Input ID: unknown, Question: Field of Study, aria-labelledby: Education-2-panel
# Previous question: Degree, Previous type: text
# Found label by aria-label: The field will alphabetically return the first 100 results and can also return specified matches.
# Input ID: unknown, Question: The field will alphabetically return the first 100 results and can also return specified matches., aria-labelledby: Education-2-panel
# Previous question: Field of Study, Previous type: unknown
# Found label by ID: Overall Result (GPA)
# Input ID: unknown, Question: Overall Result (GPA), aria-labelledby: Education-2-panel
# Previous question: The field will alphabetically return the first 100 results and can also return specified matches., Previous type: button
# Found label by form field: From
# Input ID: dateSectionYear-input, Question: From, aria-labelledby: Education-2-panel
# Previous question: Overall Result (GPA), Previous type: text
# Found label by form field: To (Actual or Expected)
# Input ID: dateSectionYear-input, Question: To (Actual or Expected), aria-labelledby: Education-2-panel
# Previous question: From, Previous type: spinbutton
# Input ID: add-button, Question: UNLABELED, aria-labelledby: Education-section
# Previous question: To (Actual or Expected), Previous type: spinbutton
# Panel Elements Count: 9
# Element: UNLABELED, Type: unknown, Options: None
# Element: School or University, Type: text, Options: None
# Element: Degree, Type: button, Options: ['Select One', 'Post-diploma studies', 'BTECH', 'MTECH', 'University Diploma', 'Associates', 'Technical/other training', 'Some college', 'PhD', 'Some post college', 'No Degree', 'MBA', 'Masters', 'Juris Doctor', 'High School', 'Doctorate', 'Bachelors']
# Element: Degree, Type: text, Options: None
# Element: Field of Study, Type: unknown, Options: None
# Element: The field will alphabetically return the first 100 results and can also return specified matches., Type: button, Options: None
# Element: Overall Result (GPA), Type: text, Options: None
# Element: From, Type: spinbutton, Options: None
# Element: To (Actual or Expected), Type: spinbutton, Options: None
# AI Response: {'[UNLABELED, unknown, unknown, Education-2-panel, button]': 'SKIP', '[School or University, unknown, text, Education-2-panel, input]': 'University of Pune', '[Degree, listbox, button, Education-2-panel, button]': 'Bachelors', '[Degree, unknown, text, Education-2-panel, input]': 'Bachelor of Engineering in Computer Science', '[Field of Study, unknown, unknown, Education-2-panel, input]': 'Computer Science', '[The field will alphabetically return the first 100 results and can also return specified matches., unknown, button, Education-2-panel, button]': 'SKIP', '[Overall Result (GPA), unknown, text, Education-2-panel, input]': 'SKIP', '[From, dateSectionYear-input, spinbutton, Education-2-panel, input]': '2011', '[To (Actual or Expected), dateSectionYear-input, spinbutton, Education-2-panel, input]': '2015'}
# Filling element unknown with response: SKIP
# Skipping input unknown as per AI response
# Filling element unknown with response: University of Pune
# Filled unknown with: University of Pune
# Filling element listbox with response: Bachelors
# Selected option: Bachelors
# Filling element unknown with response: Bachelor of Engineering in Computer Science
# Error filling element unknown: ElementHandle.fill: Timeout 30000ms exceeded.
# Call log:
#     - fill("Bachelor of Engineering in Computer Science")
#   - attempting fill action
#     2 × waiting for element to be visible, enabled and editable
#       - element is not visible
#     - retrying fill action
#     - waiting 20ms
#     2 × waiting for element to be visible, enabled and editable
#       - element is not visible
#     - retrying fill action
#       - waiting 100ms
#     60 × waiting for element to be visible, enabled and editable
#        - element is not visible
#      - retrying fill action
#        - waiting 500ms
#
# Filling element unknown with response: Computer Science
# Filling MultiInputContainer for unknown with responses: ['Computer Science']
# Found label by ID: Field of Study
# It is single
# Adding item: Computer Science
# Found 5 options for 'Computer Science':
#   - Computational Science & Engineering
#   - Computer & Info Science
#   - Computer Science
# Selected: 'Computer Science' (score: 100.0)
# Successfully added item: Computer Science
# Filling element unknown with response: SKIP
# Skipping input unknown as per AI response
# Filling element unknown with response: SKIP
# Skipping input unknown as per AI response
# Filling element dateSectionYear-input with response: 2011
# Filled spinbutton dateSectionYear-input with: 2011
# Filling element dateSectionYear-input with response: 2015
# Filled spinbutton dateSectionYear-input with: 2015
#
# === Processing section: Skills-section ===
# Processing Skills section
# Found label by ID: Type to Add Skills
# Filling element skills--skills with response: ['C#', 'TypeScript', 'Python', 'Azure', 'Angular', 'RxJS', 'SignalR']
# Filling MultiInputContainer for skills--skills with responses: ['C#', 'TypeScript', 'Python', 'Azure', 'Angular', 'RxJS', 'SignalR']
# Found label by ID: Type to Add Skills
# It is single
# Adding item: C#
# Found 23 options for 'C#':
#   - C#
# Selected: 'C#' (score: 100.0)
# Successfully added item: C#
# Adding item: TypeScript
# Found 15 options for 'TypeScript':
#   - TypeScript
# Selected: 'TypeScript' (score: 100.0)
# Successfully added item: TypeScript
# Adding item: Python
# Found 22 options for 'Python':
#   - Python (Programming Language)
#   - IronPython
#   - Pyth (Procedural Programming Language)
#   - PL/SQL (Programming Language)
#   - Python IDLE
#   - Python for Data Analysis
#   - Maya Python
#   - Python Sqlite3
#   - Python Software Development
#   - Python Numpy
#   - Flask (Web Framework)
#   - VPython
#   - Python Frameworks
#   - Django Web Framework
#   - C++ Programming Language
#   - Pandas Python Library
#   - Python Requests
#   - Python Datetime Module
#   - Python Matplotlib
#   - Python Automation
#   - Python for ArcGIS
#   - Python
# Selected: 'Python' (score: 100.0)
# Successfully added item: Python
# Adding item: Azure
# Found 23 options for 'Azure':
#   - Azure
# Selected: 'Azure' (score: 100.0)
# Successfully added item: Azure
# Adding item: Angular
# Found 15 options for 'Angular':
#   - Angular
# Selected: 'Angular' (score: 100.0)
# Successfully added item: Angular
# Adding item: RxJS
# Found 16 options for 'RxJS':
#   - Reactive Extensions for JavaScript (RxJS)
#   - Java Management Extensions (JMX)
#   - JavaScript Open Notation (JSON) Scripting
#   - JavaScript Integration
#   - JavaScript Object Notation (JSON)
#   - Reactive Extensions
#   - Adaptive Software Development (ASD)
#   - Java API for RESTful Web Services (JAX-RS)
#   - Java API for JSON Processing
#   - Java Native Interface (JNI)
#   - ExtendScript
#   - JavaScript
#   - JavaScript (jQuery)
#   - Xml Jquery
#   - JMP Scripting Language (JSL)
#   - RxJS
# Selected: 'RxJS' (score: 100.0)
# Successfully added item: RxJS
# Adding item: SignalR
# Found 23 options for 'SignalR':
#   - SignalR
# Selected: 'SignalR' (score: 100.0)
# Successfully added item: SignalR
#
# === Processing section: Resume/CV-section ===
# Processing Resume section
# Uploaded resume: /Users/mjolnir/Downloads/Lin Mei_Experiened Level Software.pdf
#
# === Processing section: Websites-section ===
# Unknown section type: Websites-section
# Processing Generic section: Websites-section
# Filling element unknown with response: SKIP
# Skipping input unknown as per AI response
#
# === Processing section: Social-Network-URLs-section ===
# Processing Work Experience section
# Found 2 experience entries
#
# === Filling experience 1 ===
# Found label by ID: Please provide a link to your LinkedIn profile:
# Input ID: unknown, Question: Please provide a link to your LinkedIn profile:, aria-labelledby: Social-Network-URLs-section
# Previous question: None, Previous type: None
#
# === Filling experience 2 ===
# Found label by ID: Please provide a link to your LinkedIn profile:
# Input ID: unknown, Question: Please provide a link to your LinkedIn profile:, aria-labelledby: Social-Network-URLs-section
# Previous question: None, Previous type: None

# %%
await bot.page.click('button[data-automation-id="pageFooterNextButton"]')

# %%
await asyncio.sleep(5)

await bot._process_later_sections(bot.page)
# Out:
# Processing Personal Information section
# Previous question: None, Current question: Are you legally authorized to work in the United States?, previous type : None, current_role : None
# --------------------------------
# Processing element 1: Input ID: listbox, Question: Are you legally authorized to work in the United States?, Type: button
# Processing form element: Are you legally authorized to work in the United States?
# AI response for field 'Are you legally authorized to work in the United States?': Yes
# Selected option: Yes
# Previous question: Are you legally authorized to work in the United States?, Current question: Are you legally authorized to work in the United States?, previous type : button, current_role : None
# ⏩ Skipping duplicate question at index 2: 'Are you legally authorized to work in the United States?'
# Previous question: Are you legally authorized to work in the United States?, Current question: Will you now or in the future require sponsorship for employment visa status (e.g. H-1B visa status)?, previous type : button, current_role : None
# --------------------------------
# Processing element 3: Input ID: listbox, Question: Will you now or in the future require sponsorship for employment visa status (e.g. H-1B visa status)?, Type: button
# Processing form element: Will you now or in the future require sponsorship for employment visa status (e.g. H-1B visa status)?
# AI response for field 'Will you now or in the future require sponsorship for employment visa status (e.g. H-1B visa status)?': No
# Selected option: No
# Previous question: Will you now or in the future require sponsorship for employment visa status (e.g. H-1B visa status)?, Current question: Will you now or in the future require sponsorship for employment visa status (e.g. H-1B visa status)?, previous type : button, current_role : None
# ⏩ Skipping duplicate question at index 4: 'Will you now or in the future require sponsorship for employment visa status (e.g. H-1B visa status)?'
# Clicking Next button

# %%
await asyncio.sleep(5)
await bot._process_later_sections(section)
# Out:
# Processing Personal Information section
# Found label by ID: What is your ethnicity?*
# Previous question: None, Current question: What is your ethnicity?, previous type : None, current_role : None
# --------------------------------
# Processing element 1: Input ID: listbox, Question: What is your ethnicity?, Type: button
# Processing form element: What is your ethnicity?
# AI response for field 'What is your ethnicity?': Asian (Not Hispanic or Latino) (United States of America)
# Selected option: Asian (Not Hispanic or Latino) (United States of America)
# Found label by form field: What is your ethnicity?*
# Previous question: What is your ethnicity?, Current question: What is your ethnicity?, previous type : button, current_role : None
# ⏩ Skipping duplicate question at index 2: 'What is your ethnicity?'
# Found label by ID: What is your gender?*
# Previous question: What is your ethnicity?, Current question: What is your gender?, previous type : button, current_role : None
# --------------------------------
# Processing element 3: Input ID: listbox, Question: What is your gender?, Type: button
# Processing form element: What is your gender?
# AI response for field 'What is your gender?': Female
# Selected option: Female
# Found label by form field: What is your gender?*
# Previous question: What is your gender?, Current question: What is your gender?, previous type : button, current_role : None
# ⏩ Skipping duplicate question at index 4: 'What is your gender?'
# Found label by ID: Do you identify as one of the following protected veterans (Disabled Veteran, Recently Separated Veteran, Active Duty Wartime or Campaign Badge Veteran, Armed Forces Service Medal Veteran)?*
# Previous question: What is your gender?, Current question: Do you identify as one of the following protected veterans (Disabled Veteran, Recently Separated Veteran, Active Duty Wartime or Campaign Badge Veteran, Armed Forces Service Medal Veteran)?, previous type : button, current_role : None
# --------------------------------
# Processing element 5: Input ID: listbox, Question: Do you identify as one of the following protected veterans (Disabled Veteran, Recently Separated Veteran, Active Duty Wartime or Campaign Badge Veteran, Armed Forces Service Medal Veteran)?, Type: button
# Processing form element: Do you identify as one of the following protected veterans (Disabled Veteran, Recently Separated Veteran, Active Duty Wartime or Campaign Badge Veteran, Armed Forces Service Medal Veteran)?
# AI response for field 'Do you identify as one of the following protected veterans (Disabled Veteran, Recently Separated Veteran, Active Duty Wartime or Campaign Badge Veteran, Armed Forces Service Medal Veteran)?': I AM NOT A VETERAN
# Selected option: I AM NOT A VETERAN
# Found label by form field: Do you identify as one of the following protected veterans (Disabled Veteran, Recently Separated Veteran, Active Duty Wartime or Campaign Badge Veteran, Armed Forces Service Medal Veteran)?*
# Previous question: Do you identify as one of the following protected veterans (Disabled Veteran, Recently Separated Veteran, Active Duty Wartime or Campaign Badge Veteran, Armed Forces Service Medal Veteran)?, Current question: Do you identify as one of the following protected veterans (Disabled Veteran, Recently Separated Veteran, Active Duty Wartime or Campaign Badge Veteran, Armed Forces Service Medal Veteran)?, previous type : button, current_role : None
# ⏩ Skipping duplicate question at index 6: 'Do you identify as one of the following protected veterans (Disabled Veteran, Recently Separated Veteran, Active Duty Wartime or Campaign Badge Veteran, Armed Forces Service Medal Veteran)?'
# Found label by ID: By selecting the checkbox, you agree to our Terms and Conditions and Applicant Privacy Policy.*
# Previous question: Do you identify as one of the following protected veterans (Disabled Veteran, Recently Separated Veteran, Active Duty Wartime or Campaign Badge Veteran, Armed Forces Service Medal Veteran)?, Current question: By selecting the checkbox, you agree to our Terms and Conditions and Applicant Privacy Policy., previous type : button, current_role : None
# --------------------------------
# Processing element 7: Input ID: unknown, Question: By selecting the checkbox, you agree to our Terms and Conditions and Applicant Privacy Policy., Type: checkbox
# Processing form element: By selecting the checkbox, you agree to our Terms and Conditions and Applicant Privacy Policy.
# AI response for field 'By selecting the checkbox, you agree to our Terms and Conditions and Applicant Privacy Policy.': True
# Checked checkbox unknown
# Clicking Next button

# %%
await asyncio.sleep(5)
await bot._process_later_sections(section)
# Out:
# Processing Personal Information section
# Found label by ID: Language*
# Previous question: None, Current question: Language, previous type : None, current_role : None
# --------------------------------
# Processing element 1: Input ID: listbox, Question: Language, Type: button
# Processing form element: Language
# AI response for field 'Language': English
# Selected option: English
# Found label by form field: Language*
# Previous question: Language, Current question: Language, previous type : button, current_role : None
# ⏩ Skipping duplicate question at index 2: 'Language'
# Found label by ID: Name*
# Previous question: Language, Current question: Name, previous type : button, current_role : None
# --------------------------------
# Processing element 3: Input ID: unknown, Question: Name, Type: text
# Processing form element: Name
# AI response for field 'Name': Lin Mei
# Filled unknown with: Lin Mei
# Found label by ID: Employee ID (if applicable)
# Previous question: Name, Current question: Employee ID (if applicable), previous type : text, current_role : None
# --------------------------------
# Processing element 4: Input ID: unknown, Question: Employee ID (if applicable), Type: text
# Processing form element: Employee ID (if applicable)
# AI response for field 'Employee ID (if applicable)': N/A
# Filled unknown with: N/A
# Found label by form field: Date*
# Day: 08, Month: 08, Year: 2025
# Filled spinbutton selfIdentifiedDisabilityData-month with: 08
# Filled date field selfIdentifiedDisabilityData-month with: 08
# Found label by form field: Date*
# Day: 08, Month: 08, Year: 2025
# Filled spinbutton selfIdentifiedDisabilityData-day with: 08
# Filled date field selfIdentifiedDisabilityData-day with: 08
# Found label by form field: Date*
# Day: 08, Month: 08, Year: 2025
# Filled spinbutton selfIdentifiedDisabilityData-year with: 2025
# Filled date field selfIdentifiedDisabilityData-year with: 2025
# Found label by form field: Date*
# Previous question: Employee ID (if applicable), Current question: Date, previous type : text, current_role : button
# --------------------------------
# Processing element 8: Input ID: dateIcon, Question: Date, Type: unknown
# Processing form element: Date
# AI response for field 'Date': 2023-10-06
# Unhandled element type: div/unknown for dateIcon
# Found label by ID: Yes, I have a disability, or have had one in the past
# Previous question: Date, Current question: Yes, I have a disability, or have had one in the past, previous type : unknown, current_role : None
# --------------------------------
# Processing element 9: Input ID: unknown, Question: Yes, I have a disability, or have had one in the past, Type: checkbox
# Processing form element: Yes, I have a disability, or have had one in the past
# AI response for field 'Yes, I have a disability, or have had one in the past': False
# Found label by ID: No, I do not have a disability and have not had one in the past
# Previous question: Yes, I have a disability, or have had one in the past, Current question: No, I do not have a disability and have not had one in the past, previous type : checkbox, current_role : None
# --------------------------------
# Processing element 10: Input ID: unknown, Question: No, I do not have a disability and have not had one in the past, Type: checkbox
# Processing form element: No, I do not have a disability and have not had one in the past
# AI response for field 'No, I do not have a disability and have not had one in the past': True
# Checked checkbox unknown
# Found label by ID: I do not want to answer
# Previous question: No, I do not have a disability and have not had one in the past, Current question: I do not want to answer, previous type : checkbox, current_role : None
# --------------------------------
# Processing element 11: Input ID: unknown, Question: I do not want to answer, Type: checkbox
# Processing form element: I do not want to answer
# AI response for field 'I do not want to answer': False
# Clicking Next button
